# %% [markdown]
# <a href="https://www.kaggle.com/code/hansikakarra/practice-ai-with-kaggle?scriptVersionId=244471067" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def add_three(input): # add_three() - user difined function
    output = input + 3
    if output < 15:
        print("smaller than 20")
    else:
        print("larger than 20")
    return output

result = add_three(20)
print(result)
# Out:
# larger than 20
# 23
