# %% [markdown]
# <a href="https://www.kaggle.com/code/hansikakarra/practiceaiwithkaggle?scriptVersionId=244469032" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print("Hello World!")
# Out:
# Hello World!
